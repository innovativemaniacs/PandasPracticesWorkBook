# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("kkk.csv")
df
# Out:
#        Year  Month  Day  Location  Casualties               Cause Weather  \
# 0      1998      1   27       844          31     Technical Fault   Clear
# 1      1961      6   23       387          40         Human Error   Clear
# 2      2018      2    7       506          22  Weather Conditions   Rainy
# 3      2007      7   15       294          31         Human Error  Stormy
# 4      1967      9   14       193          28     Technical Fault   Clear
# ...     ...    ...  ...       ...         ...                 ...     ...
# 99995  1955      6   24       689          26            Sabotage   Clear
# 99996  1995      7    7       344          30     Technical Fault   Foggy
# 99997  2010      4   15       839          33         Human Error  Stormy
# 99998  2023      3   23       192          34     Technical Fault   Clear
# 99999  2009      4   10       356          28         Human Error   Rainy
#
#        Train Speed  Maintenance Status  Signal Error
# ...

# %%
df=df[(df["Year"]>=1947) & (df["Year"]<=2024)]
df
# Out:
#        Year  Month  Day  Location  Casualties               Cause Weather  \
# 0      1998      1   27       844          31     Technical Fault   Clear
# 1      1961      6   23       387          40         Human Error   Clear
# 2      2018      2    7       506          22  Weather Conditions   Rainy
# 3      2007      7   15       294          31         Human Error  Stormy
# 4      1967      9   14       193          28     Technical Fault   Clear
# ...     ...    ...  ...       ...         ...                 ...     ...
# 99995  1955      6   24       689          26            Sabotage   Clear
# 99996  1995      7    7       344          30     Technical Fault   Foggy
# 99997  2010      4   15       839          33         Human Error  Stormy
# 99998  2023      3   23       192          34     Technical Fault   Clear
# 99999  2009      4   10       356          28         Human Error   Rainy
#
#        Train Speed  Maintenance Status  Signal Error
# ...

# %%
new_filtered_df=df.groupby(["Year", "Cause"]).size().reset_index(name="count").sort_values("count", ascending=False)
new_filtered_df

df_Year_between_1947_to2024=new_filtered_df[(new_filtered_df["Year"]>=1947) & (new_filtered_df["Year"]<=2025)]
df_Year_between_1947_to2024
# Out:
#      Year        Cause  count
# 125  1972  Human Error    710
# 10   1949  Human Error    710
# 145  1976  Human Error    703
# 235  1994  Human Error    693
# 250  1997  Human Error    692
# ..    ...          ...    ...
# 173  1981      Unknown     52
# 151  1977     Sabotage     51
# 116  1970     Sabotage     50
# 206  1988     Sabotage     47
# 348  2016      Unknown     41
#
# [385 rows x 3 columns]

# %%
# yearwise casualties
casualties_by_year = df_Year_between_1947_to2024.groupby("Year")["count"].sum().reset_index()
casualties_by_year
# Out:
#     Year  count
# 0   1947   1291
# 1   1948   1340
# 2   1949   1320
# 3   1950   1333
# 4   1951   1341
# ..   ...    ...
# 72  2019   1269
# 73  2020   1301
# 74  2021   1289
# 75  2022   1254
# 76  2023   1291
#
# [77 rows x 2 columns]

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data=casualties_by_year, x="Year", y="count", errorbar=None)

plt.title("Trend of Total Casualties from 1947 to 2024")
plt.xlabel("Year")
plt.ylabel("Number of Casualties")
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 12))
ax = sns.barplot(data=casualties_by_year, x="Year", y="count", errorbar=None)


for container in ax.containers:
    ax.bar_label(container, fontsize=8, rotation=90)

plt.title("Trend of Total Casualties from 1947 to 2024")
plt.xlabel("Year")
plt.ylabel("Number of Casualties")
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_Year_between_1947_to2024.to_csv("dataset Between_1947_2024.csv" ,index=False)
